# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathanminterdev/ThinkPythonAssignments/blob/main/Week3/bio_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Statements

# Function Definitions

# Program Logic
# Assign values to variables: name, goal, birth_year, current_year
# Calculate Age
# Print top border
# Print bio sentence
# Print bottom border
